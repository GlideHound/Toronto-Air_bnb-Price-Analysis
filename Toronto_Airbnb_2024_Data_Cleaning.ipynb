# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read the csv file
df = pd.read_csv("Toronto_Airbnb_Data.csv")
df = df.replace("?", np.nan)

# %%
# display the first five rows of the dataset to get an overview
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   1419   https://www.airbnb.com/rooms/1419  20240412141305   2024-04-13
# 1   8077   https://www.airbnb.com/rooms/8077  20240412141305   2024-04-13
# 2  26654  https://www.airbnb.com/rooms/26654  20240412141305   2024-04-13
# 3  27423  https://www.airbnb.com/rooms/27423  20240412141305   2024-04-13
# 4  30931  https://www.airbnb.com/rooms/30931  20240412141305   2024-04-13
#
#             source                                               name  \
# 0  previous scrape                    Beautiful home in amazing area!
# 1  previous scrape                 Downtown Harbourfront Private Room
# 2      city scrape  World Class @ CN Tower, convention centre, The...
# 3      city scrape        Executive Studio Unit- Ideal for One Person
# 4  previous scrape                 Downtown Toronto - Waterview Condo
#
#                                          description  \
# ...

# %%
# display the information of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20650 entries, 0 to 20649
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            20650 non-null  int64
#  1   listing_url                                   20650 non-null  object
#  2   scrape_id                                     20650 non-null  int64
#  3   last_scraped                                  20650 non-null  object
#  4   source                                        20650 non-null  object
#  5   name                                          20650 non-null  object
#  6   description                                   20181 non-null  object
#  7   neighborhood_overview                         11103 non-null  object
#  8   picture_url                                   20650 non-null  object
# ...

# %%
# Remove the dollar sign from the 'price' column and convert price to float64
df['price'] = df['price'].astype(str).str.replace('[$,]', '', regex=True)
df['price'] = df['price'].astype('float')

# %%
# replace the NaN value in price column with the calculated mean
price_avg = df['price'].mean()
df['price'] = df['price'].replace(np.nan, price_avg)

# %%
df['price']
# Out:
# 0        183.018895
# 1        183.018895
# 2        145.000000
# 3         75.000000
# 4        183.018895
#             ...
# 20645    288.000000
# 20646    120.000000
# 20647    224.000000
# 20648    130.000000
# 20649    250.000000
# Name: price, Length: 20650, dtype: float64

# %%
# Delete rows with the NaN values in column host_is_superhost, convert it to boolean
df = df.dropna(subset=['host_is_superhost'])
df['host_is_superhost'] = df['host_is_superhost'].astype(bool)

# %%
df['host_is_superhost']
# Out:
# 0        f
# 1        f
# 2        f
# 3        f
# 4        f
#         ..
# 20645    f
# 20646    f
# 20647    f
# 20648    t
# 20649    f
# Name: host_is_superhost, Length: 20650, dtype: object

# %%
# Last step, save the cleaned dataframe in a csv file
df.to_csv('Cleaned_Toronto_Airbnb_Data.csv', index=False)
print("saved!")
# Out:
# saved!
